# %%
import os
import librosa
import numpy as np
import matplotlib.pyplot as plt

def split_and_create_mel_spectrograms(input_file, output_dir):
    # Load the audio file
    audio, sr = librosa.load(input_file, sr=44100)
    
    # Split the audio into segments of 1 seconds each
    segment_duration = 1.5  # seconds
    segment_samples = int(segment_duration * sr)
    num_segments = len(audio) // segment_samples
    
    # Create the output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    

        
    # Compute the mel spectrogram
    mel_spec = librosa.feature.melspectrogram(y=audio, sr=sr, hop_length=345)
    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)

    print(mel_spec_db.shape)
    
    # Save the mel spectrogram as an image
    output_file = os.path.join(output_dir, f"mel_spec.png")
    plt.imsave(output_file, mel_spec_db, origin='lower', cmap='gray')
    
    # audio = librosa.feature.inverse.mel_to_audio(mel_spec_db)
    # output_file_audio = os.path.join(output_dir, f"mel_spec_{i}.wav")
    # import soundfile as sf
    # sf.write(output_file_audio, audio, 44100, 'PCM_24')


    print(f"Created mel spectrogram: {output_file}")
    print(sr)

# Usage example
input_file = "/Users/user/Library/CloudStorage/OneDrive-Personal/Mac/Danseuses_de_Delphes.wav"
output_dir = "/Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2"
split_and_create_mel_spectrograms(input_file, output_dir)
# Out:
# (128, 23804)
# Created mel spectrogram: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/mel_spec.png
# 44100

# %%
from PIL import Image
import os

# Load the image
image_path = "/Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/mel_spec.png"
image = Image.open(image_path)

# Get the width and height of the image
width, height = image.size

# Calculate the number of segments
num_segments = width // 128

# Create the output directory if it doesn't exist
output_dir = "/Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2"
os.makedirs(output_dir, exist_ok=True)

# Split the image into segments
for i in range(num_segments):
    # Calculate the starting and ending coordinates for each segment
    start_x = i * 128
    end_x = start_x + 128

    # Crop the image segment
    segment = image.crop((start_x, 0, end_x, height))

    # Save the segment as a .png image
    segment_path = os.path.join(output_dir, f"segment_{i}.png")
    segment.save(segment_path)

    print(f"Created segment: {segment_path}")
# Out:
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_0.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_1.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_2.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_3.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_4.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_5.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_6.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_7.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_8.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_9.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_10.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_11.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_12.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_13.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_14.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_15.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_16.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_17.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_18.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_19.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_20.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_21.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_22.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_23.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_24.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_25.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_26.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_27.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_28.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_29.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_30.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_31.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_32.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_33.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_34.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_35.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_36.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_37.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_38.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_39.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_40.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_41.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_42.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_43.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_44.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_45.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_46.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_47.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_48.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_49.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_50.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_51.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_52.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_53.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_54.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_55.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_56.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_57.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_58.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_59.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_60.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_61.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_62.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_63.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_64.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_65.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_66.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_67.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_68.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_69.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_70.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_71.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_72.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_73.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_74.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_75.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_76.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_77.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_78.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_79.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_80.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_81.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_82.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_83.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_84.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_85.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_86.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_87.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_88.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_89.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_90.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_91.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_92.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_93.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_94.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_95.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_96.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_97.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_98.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_99.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_100.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_101.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_102.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_103.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_104.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_105.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_106.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_107.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_108.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_109.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_110.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_111.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_112.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_113.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_114.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_115.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_116.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_117.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_118.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_119.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_120.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_121.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_122.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_123.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_124.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_125.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_126.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_127.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_128.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_129.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_130.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_131.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_132.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_133.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_134.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_135.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_136.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_137.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_138.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_139.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_140.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_141.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_142.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_143.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_144.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_145.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_146.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_147.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_148.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_149.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_150.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_151.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_152.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_153.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_154.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_155.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_156.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_157.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_158.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_159.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_160.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_161.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_162.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_163.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_164.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_165.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_166.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_167.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_168.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_169.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_170.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_171.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_172.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_173.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_174.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_175.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_176.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_177.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_178.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_179.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_180.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_181.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_182.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_183.png
# Created segment: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_184.png

# %%
import os
import librosa
import soundfile as sf

# Directory containing the .png mel spectrograms
input_dir = "/Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2"

# Output directory for the .wav files
output_dir = "/Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/wav_files"

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Convert each .png mel spectrogram to .wav file
for filename in os.listdir(input_dir):
    if filename.endswith(".png"):
        # Get the path of the .png mel spectrogram
        input_file = os.path.join(input_dir, filename)
        
        # Load the .png mel spectrogram as an image
        image = Image.open(input_file)

        # Convert the image to a numpy array
        mel_spec_db = np.array(image)

        mel_spec=librosa.db_to_power(mel_spec_db, ref=1)
        mel_spec_2 = mel_spec[:, :, 1]

        print(mel_spec.shape)
        # Convert the mel spectrogram back to audio
        audio = librosa.feature.inverse.mel_to_audio(mel_spec_2)

        # Output .wav file path
        output_file = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}.wav")
        
        # Save the audio as a .wav file
        sf.write(output_file, audio, 44100)
        
        print(f"Created .wav file: {output_file}")
# Out:
# (128, 128, 4)
# Created .wav file: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/wav_files/segment_0.wav

# %%
input_file = '/Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_81.png'

image = Image.open(input_file)

# Convert the image to a numpy array
mel_spec_db = np.array(image)

mel_spec=librosa.db_to_power(mel_spec_db, ref=1)
mel_spec_2 = mel_spec[:, :, 1]

print(mel_spec.shape)
# Convert the mel spectrogram back to audio
audio = librosa.feature.inverse.mel_to_audio(mel_spec_2)

# Output .wav file path
output_file = "/Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_81.wav"

# Save the audio as a .wav file
sf.write(output_file, audio, 44100)

print(f"Created .wav file: {output_file}")
# Out:
# (128, 128, 4)
# Created .wav file: /Users/user/Library/CloudStorage/OneDrive-Personal/Mac/PhD/Spect2/segment_81.wav
